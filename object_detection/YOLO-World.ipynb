# %%
from ultralytics import YOLO
from PIL import Image

# Load a model
model = YOLO("yolov8x-worldv2.pt", )  # load an official model

# %%
model.set_classes([
    "Calendar",
    "Two highlighters",
    "Desk lamp",
    "Book",
    "Pen",
    "Mouse",
    "Phone",
    "Fan",
    "Water bottle",
    "Charger"])

results = model.predict("/home/jupyter/project/research/experiments/table.jpeg", save=True)
# Out:
# 100%|███████████████████████████████████████| 338M/338M [00:20<00:00, 16.9MiB/s]
# image 1/1 /home/jupyter/project/research/experiments/table.jpeg: 448x640 1 Desk lamp, 1 Book, 3 Pens, 2 Mouses, 1 Fan, 1 Water bottle, 36.9ms
# Speed: 1.3ms preprocess, 36.9ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /home/jupyter/project/research/object_detection/runs/detect/predict
